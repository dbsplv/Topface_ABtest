# %% [markdown]
# # Анализ популярности анкет Topface. A/B тест.
# ## Сбор Данных.

# %% [markdown]
# ![topface.jpg](attachment:topface.jpg)

# %%
import pandas as pd
import numpy as np
from datetime import datetime


import psycopg2
from sqlalchemy import create_engine

con = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/postgres')

# %%
name = 'Саша'
age = 24
city='Москва'

# %% [markdown]
# День 1 (1.06.2022)

# %%
date = '1.06.2022'

aa_day_1 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[28,32] , 
                     'guests':[35,29],
                     'post_likes' :[22,28]
})
aa_day_1
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  1.06.2022     28      35          22
# 1  Саша   24  Москва   AA2  1.06.2022     32      29          28

# %%
date = '2.06.2022'

aa_day_2 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[39,37] , 
                     'guests':[42,40],
                     'post_likes' :[37,34]
})
aa_day_2
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  2.06.2022     39      42          37
# 1  Саша   24  Москва   AA2  2.06.2022     37      40          34

# %%
date = '3.06.2022'

aa_day_3 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[40,38] , 
                     'guests':[56,50],
                     'post_likes' :[37,36]
})
aa_day_3
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  3.06.2022     40      56          37
# 1  Саша   24  Москва   AA2  3.06.2022     38      50          36

# %%
date = '4.06.2022'

aa_day_4 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[38,40] , 
                     'guests':[74,62],
                     'post_likes' :[36,34]
})
aa_day_4
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  4.06.2022     38      74          36
# 1  Саша   24  Москва   AA2  4.06.2022     40      62          34

# %%
date = '5.06.2022'

aa_day_5 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[42,37] , 
                     'guests':[86,71],
                     'post_likes' :[37,33]
})
aa_day_5
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  5.06.2022     42      86          37
# 1  Саша   24  Москва   AA2  5.06.2022     37      71          33

# %%
date = '6.06.2022'

aa_day_6 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[38,40] , 
                     'guests':[74,62],
                     'post_likes' :[36,34]
})
aa_day_6
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  6.06.2022     38      74          36
# 1  Саша   24  Москва   AA2  6.06.2022     40      62          34

# %%
date = '7.06.2022'

aa_day_7 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[45,48] , 
                     'guests':[89,71],
                     'post_likes' :[42,45]
})
aa_day_7
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  7.06.2022     45      89          42
# 1  Саша   24  Москва   AA2  7.06.2022     48      71          45

# %%
date = '8.06.2022'

aa_day_8 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[54,58] , 
                     'guests':[97,81],
                     'post_likes' :[50,55]
})
aa_day_8
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  8.06.2022     54      97          50
# 1  Саша   24  Москва   AA2  8.06.2022     58      81          55

# %%
date = '9.06.2022'

aa_day_9 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[66,71] , 
                     'guests':[117,125],
                     'post_likes' :[62,68]
})
aa_day_9
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  9.06.2022     66     117          62
# 1  Саша   24  Москва   AA2  9.06.2022     71     125          68

# %%
date = '10.06.2022'

aa_day_10 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[71,73] , 
                     'guests':[133,141],
                     'post_likes' :[66,64]
})
aa_day_10
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  10.06.2022     71     133          66
# 1  Саша   24  Москва   AA2  10.06.2022     73     141          64

# %%
date = '11.06.2022'

aa_day_11 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[70,66] , 
                     'guests':[140,147],
                     'post_likes' :[69,61]
})
aa_day_11
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  11.06.2022     70     140          69
# 1  Саша   24  Москва   AA2  11.06.2022     66     147          61

# %%
date = '12.06.2022'

aa_day_12 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[74,62] , 
                     'guests':[154,151],
                     'post_likes' :[69,60]
})
aa_day_12
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  12.06.2022     74     154          69
# 1  Саша   24  Москва   AA2  12.06.2022     62     151          60

# %%
date = '13.06.2022'

aa_day_13 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[71,64] , 
                     'guests':[159,163],
                     'post_likes' :[68,63]
})
aa_day_13
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  13.06.2022     71     159          68
# 1  Саша   24  Москва   AA2  13.06.2022     64     163          63

# %%
date = '14.06.2022'

aa_day_14 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['AA1','AA2'], 
                     'date':[date,date], 
                     'likes':[77,70] , 
                     'guests':[171,178],
                     'post_likes' :[75,64]
})
aa_day_14
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва   AA1  14.06.2022     77     171          75
# 1  Саша   24  Москва   AA2  14.06.2022     70     178          64

# %%
aa_test_data = pd.concat([aa_day_1, aa_day_2, aa_day_3, aa_day_4, aa_day_5, aa_day_6, aa_day_7,
                          aa_day_8, aa_day_9, aa_day_10, aa_day_11, aa_day_12, aa_day_13, aa_day_14] , ignore_index=True)
aa_test_data.date = [ datetime.strptime(x, '%d.%m.%Y') for x in  aa_test_data.date]
aa_test_data
# Out:
#     name  age    city group       date  likes  guests  post_likes
# 0   Саша   24  Москва   AA1 2022-06-01     28      35          22
# 1   Саша   24  Москва   AA2 2022-06-01     32      29          28
# 2   Саша   24  Москва   AA1 2022-06-02     39      42          37
# 3   Саша   24  Москва   AA2 2022-06-02     37      40          34
# 4   Саша   24  Москва   AA1 2022-06-03     40      56          37
# 5   Саша   24  Москва   AA2 2022-06-03     38      50          36
# 6   Саша   24  Москва   AA1 2022-06-04     38      74          36
# 7   Саша   24  Москва   AA2 2022-06-04     40      62          34
# 8   Саша   24  Москва   AA1 2022-06-05     42      86          37
# 9   Саша   24  Москва   AA2 2022-06-05     37      71          33
# 10  Саша   24  Москва   AA1 2022-06-06     38      74          36
# 11  Саша   24  Москва   AA2 2022-06-06     40      62          34
# 12  Саша   24  Москва   AA1 2022-06-07     45      89          42
# ...

# %%
date = '21.06.2022'

ab_day_1 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[31,35] , 
                     'guests':[40,31],
                     'post_likes' :[28,32]
})
ab_day_1
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  21.06.2022     31      40          28
# 1  Саша   24  Москва     B  21.06.2022     35      31          32

# %%
date = '22.06.2022'

ab_day_2 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[39,40] , 
                     'guests':[55,43],
                     'post_likes' :[34,32]
})
ab_day_2
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  22.06.2022     39      55          34
# 1  Саша   24  Москва     B  22.06.2022     40      43          32

# %%
date = '23.06.2022'

ab_day_3 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[43,39] , 
                     'guests':[74,69],
                     'post_likes' :[38,35]
})
ab_day_3
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  23.06.2022     43      74          38
# 1  Саша   24  Москва     B  23.06.2022     39      69          35

# %%
date = '24.06.2022'

ab_day_3 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[49,50] , 
                     'guests':[84,80],
                     'post_likes' :[42,42]
})
ab_day_3
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  24.06.2022     49      84          42
# 1  Саша   24  Москва     B  24.06.2022     50      80          42

# %%
date = '25.06.2022'

ab_day_4 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[55,57] , 
                     'guests':[93,97],
                     'post_likes' :[40,39]
})
ab_day_4
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  25.06.2022     55      93          40
# 1  Саша   24  Москва     B  25.06.2022     57      97          39

# %%
date = '26.06.2022'

ab_day_5 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[47,48] , 
                     'guests':[112,123],
                     'post_likes' :[42,45]
})
ab_day_5
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  26.06.2022     47     112          42
# 1  Саша   24  Москва     B  26.06.2022     48     123          45

# %%
date = '27.06.2022'

ab_day_6 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[44,49] , 
                     'guests':[112,123],
                     'post_likes' :[40,47]
})
ab_day_6
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  27.06.2022     44     112          40
# 1  Саша   24  Москва     B  27.06.2022     49     123          47

# %%
date = '28.06.2022'

ab_day_7 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[45,53] , 
                     'guests':[120,129],
                     'post_likes' :[43,50]
})
ab_day_7
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  28.06.2022     45     120          43
# 1  Саша   24  Москва     B  28.06.2022     53     129          50

# %%
date = '29.06.2022'

ab_day_8 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[53,59] , 
                     'guests':[136,144],
                     'post_likes' :[48,50]
})
ab_day_8
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  29.06.2022     53     136          48
# 1  Саша   24  Москва     B  29.06.2022     59     144          50

# %%
date = '30.06.2022'

ab_day_9 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[57,58] , 
                     'guests':[145,156],
                     'post_likes' :[52,55]
})
ab_day_9
# Out:
#    name  age    city group        date  likes  guests  post_likes
# 0  Саша   24  Москва     A  30.06.2022     57     145          52
# 1  Саша   24  Москва     B  30.06.2022     58     156          55

# %%
date = '1.07.2022'

ab_day_10 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[55,61] , 
                     'guests':[151,164],
                     'post_likes' :[52,56]
})
ab_day_10
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва     A  1.07.2022     55     151          52
# 1  Саша   24  Москва     B  1.07.2022     61     164          56

# %%
date = '2.07.2022'

ab_day_11 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[67,69] , 
                     'guests':[157,169],
                     'post_likes' :[61,58]
})
ab_day_11
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва     A  2.07.2022     67     157          61
# 1  Саша   24  Москва     B  2.07.2022     69     169          58

# %%
date = '3.07.2022'

ab_day_12 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[63,64] , 
                     'guests':[165,172],
                     'post_likes' :[60,59]
})
ab_day_12
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва     A  3.07.2022     63     165          60
# 1  Саша   24  Москва     B  3.07.2022     64     172          59

# %%
date = '4.07.2022'

ab_day_13 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[64,63] , 
                     'guests':[174,177],
                     'post_likes' :[63,60]
})
ab_day_13
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва     A  4.07.2022     64     174          63
# 1  Саша   24  Москва     B  4.07.2022     63     177          60

# %%
date = '5.07.2022'

ab_day_14 = pd.DataFrame({'name': [name, name], 
                     'age': [age,age],  
                     'city': ['Москва','Москва'], 
                     'group':['A','B'], 
                     'date':[date,date], 
                     'likes':[66,64] , 
                     'guests':[176,177],
                     'post_likes' :[64,61]
})
ab_day_14
# Out:
#    name  age    city group       date  likes  guests  post_likes
# 0  Саша   24  Москва     A  5.07.2022     66     176          64
# 1  Саша   24  Москва     B  5.07.2022     64     177          61

# %%
ab_test_data = pd.concat([ab_day_1, ab_day_2, ab_day_3, ab_day_4, ab_day_5, ab_day_6, ab_day_7, 
                          ab_day_8, ab_day_9, ab_day_10, ab_day_11, ab_day_12, ab_day_13, ab_day_14 ], ignore_index=True)
ab_test_data.date = [ datetime.strptime(x, '%d.%m.%Y') for x in  ab_test_data.date]
ab_test_data
# Out:
#     name  age    city group       date  likes  guests  post_likes
# 0   Саша   24  Москва     A 2022-06-21     31      40          28
# 1   Саша   24  Москва     B 2022-06-21     35      31          32
# 2   Саша   24  Москва     A 2022-06-22     39      55          34
# 3   Саша   24  Москва     B 2022-06-22     40      43          32
# 4   Саша   24  Москва     A 2022-06-24     49      84          42
# 5   Саша   24  Москва     B 2022-06-24     50      80          42
# 6   Саша   24  Москва     A 2022-06-25     55      93          40
# 7   Саша   24  Москва     B 2022-06-25     57      97          39
# 8   Саша   24  Москва     A 2022-06-26     47     112          42
# 9   Саша   24  Москва     B 2022-06-26     48     123          45
# 10  Саша   24  Москва     A 2022-06-27     44     112          40
# 11  Саша   24  Москва     B 2022-06-27     49     123          47
# 12  Саша   24  Москва     A 2022-06-28     45     120          43
# ...

# %%
aa_test_data.to_sql('aa_test_data', con, index=False,
            if_exists='replace',method='multi')
ab_test_data.to_sql('ab_test_data', con, index=False,               
            if_exists='replace',method='multi')

# %%
sql = '''select * from ab_test_data'''
pd.read_sql(sql,con)
# Out:
#     name  age    city group       date  likes  guests  post_likes
# 0   Саша   24  Москва     A 2022-06-21     31      40          28
# 1   Саша   24  Москва     B 2022-06-21     35      31          32
# 2   Саша   24  Москва     A 2022-06-22     39      55          34
# 3   Саша   24  Москва     B 2022-06-22     40      43          32
# 4   Саша   24  Москва     A 2022-06-24     49      84          42
# 5   Саша   24  Москва     B 2022-06-24     50      80          42
# 6   Саша   24  Москва     A 2022-06-25     55      93          40
# 7   Саша   24  Москва     B 2022-06-25     57      97          39
# 8   Саша   24  Москва     A 2022-06-26     47     112          42
# 9   Саша   24  Москва     B 2022-06-26     48     123          45
# 10  Саша   24  Москва     A 2022-06-27     44     112          40
# 11  Саша   24  Москва     B 2022-06-27     49     123          47
# 12  Саша   24  Москва     A 2022-06-28     45     120          43
# ...
